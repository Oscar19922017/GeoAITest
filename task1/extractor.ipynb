# %%
import pdfplumber
from pdf2image import convert_from_path
import openai
import os
import base64
import json
import pandas as pd
from dotenv import load_dotenv
from io import BytesIO
import re

def try_fix_json(text):
    if text.count("{") > text.count("}"):
        text += "}" * (text.count("{") - text.count("}"))
    if text.count("[") > text.count("]"):
        text += "]" * (text.count("[") - text.count("]"))
    text = re.sub(r',([\s]*[}}\]])', r'\1', text)
    return text

def normalize_json_rows(data):
    if isinstance(data, list) and all(isinstance(row, dict) for row in data):
        all_keys = set()
        for row in data:
            all_keys.update(row.keys())
        all_keys = list(all_keys)
        normalized = []
        for row in data:
            normalized.append({k: row.get(k, "") for k in all_keys})
        return normalized
    return data

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# Palabras clave para cada tabla
tables_to_find = {
    "key_financial_metrics": "KEY FINANCIAL METRICS",
    "key_operational_metrics": "KEY OPERATIONAL METRICS",
    "robust_cash_flow": "ROBUST CASH FLOW GENERATION FROM ELG"  # <- la nueva tabla
}
PROMPT = """
¿Hay una tabla con el encabezado '{header}' en esta imagen?
Si existe, extrae TODOS los datos de la tabla, incluyendo los nombres de las métricas (encabezados de fila y columna), en formato JSON estructurado como una lista de diccionarios (uno por fila), donde cada diccionario tenga las claves: nombre de la métrica y sus valores. No inventes nada.
Si no existe, responde solo con 'NO TABLE.
"""

start_page = 20  # Python indexa desde 0

# --- NUEVO: Recorre todos los PDFs en la carpeta ---
DATA_DIR = "data"
for filename in os.listdir(DATA_DIR):
    if filename.lower().endswith(".pdf"):
        PDF_PATH = os.path.join(DATA_DIR, filename)
        print("\n--- Procesando:", filename, "---")
        # Extraer Q y año del nombre del PDF
        match = re.search(r'(?:^|[\\/_-])(?P<year>20\d{2})[^\dA-Za-z]*(?P<q>q[1-4])', filename, re.IGNORECASE)
        if not match:
            match = re.search(r'(?P<q>q[1-4])[^\dA-Za-z]*(?P<year>20\d{2})', filename, re.IGNORECASE)
        if match:
            trimestre = match.group('q').upper()
            anio = match.group('year')
        else:
            trimestre = "QX"
            anio = "YYYY"
        
        try:
            with pdfplumber.open(PDF_PATH) as pdf:
                pages = list(pdf.pages[start_page:])
                page_numbers = list(range(start_page + 1, start_page + 1 + len(pages)))  # 1-based

            for table_key, table_header in tables_to_find.items():
                table_found = False
                for page_idx, page_num in enumerate(page_numbers):
                    # Convierte la página a imagen EN MEMORIA
                    page_img = convert_from_path(PDF_PATH, first_page=page_num, last_page=page_num, dpi=150)[0]
                    buffer = BytesIO()
                    page_img.save(buffer, format="PNG")
                    img_base64 = base64.b64encode(buffer.getvalue()).decode("utf-8")
                    prompt = PROMPT.format(header=table_header)
                    response = client.chat.completions.create(
                        model="gpt-4o",
                        messages=[
                            {
                                "role": "user",
                                "content": [
                                    {"type": "text", "text": prompt},
                                    {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img_base64}"}}
                                ]
                            }
                        ],
                        max_tokens=4096
                    )
                    content = response.choices[0].message.content.strip()
                    print(f"{table_key} - Página {page_num} respuesta GPT:\n{content[:300]}...\n")  # Solo muestra inicio

                    if "NO TABLE" not in content and "no table" not in content.lower():
                        if "```json" in content:
                            content = content.split("```json")[-1].split("```")[0]
                        elif "```" in content:
                            content = content.split("```")[-1].split("```")[0]
                        fixed_content = try_fix_json(content)
                        try:
                            data = json.loads(fixed_content)
                            data = normalize_json_rows(data)
                            df = pd.DataFrame(data)
                            # Guarda el Excel en una subcarpeta, nombrando por archivo, Q y año
                            out_name = f"{os.path.splitext(filename)[0]}_tabla_{table_key}_{trimestre}_{anio}.xlsx"
                            df.to_excel(os.path.join(DATA_DIR, out_name), index=False)
                            print(f"¡Tabla '{table_header}' encontrada en página {page_num} y guardada como {out_name}!")
                            print(df.head())
                            table_found = True
                            break
                        except Exception as e:
                            print(f"No se pudo parsear el JSON para la tabla '{table_key}'. Revisa la respuesta de OpenAI manualmente.")
                            print("Error:", e)
                            print("JSON crudo:\n", fixed_content[:1000])
                            break
                if not table_found:
                    print(f"No se encontró la tabla '{table_header}' en {filename}.")
        except Exception as err:
            print(f"Error procesando {filename}: {err}")
# Out:
# --- Procesando: 2021-q4-txg-cp.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE...
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "Metric": "Gold sold (oz)",
#         "Q1 2020": "108,064",
#         "Q2 2020": "63,147",
#         "Q3 2020": "133,036",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 23 y guardada como 2021-q4-txg-cp_tabla_key_financial_metrics_Q4_2021.xlsx!
#    Q1 2020  Q1 2021  Q3 2021  Q4 2020  Q3 2020  FY 2020  \
# 0  108,064  129,019  118,989  133,063  133,036  437,310
# 1   $1,571   $1,778   $1,786   $1,847   $1,884   $1,771
# 2   $1,333   $1,022   $1,198   $1,075   $1,154   $1,217
# 3     $794     $580     $727     $579     $633     $672
# 4     $975     $854     $900     $886     $877     $924
#
#                           Metric  Q2 2021  FY 2021 Q2 2020  Q4 2021
# 0                 Gold sold (oz)  111,424  468,823  63,147  109,391
# 1     Realized gold price ($/oz)   $1,816   $1,794  $1,712   $1,798
# 2           Cost of sales ($/oz)   $1,074   $1,129  $1,447   $1,235
# 3         Total cash cost ($/oz)     $637     $674    $740     $764
# 4  All-in sustaining cost ($/oz)     $897     $928  $1,015   $1,079
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Ore mined (kt)",
#         "Q1 2020": "1,736",
#         "Q2 2020": "666",
#         "Q3 2020": "1,407",
#         "Q4 2020": "1,689",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "FY 2020": "5,498",...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 22 y guardada como 2021-q4-txg-cp_tabla_key_operational_metrics_Q4_2021.xlsx!
#   Q1 2020 Q1 2021 Q3 2021 Q4 2020 Q3 2020 FY 2020 FY 2021 Q2 2021 Q2 2020  \
# 0   1,736   1,359   1,406   1,689   1,407   5,498   4,761   1,131     666
# 1  11,726   9,882   7,476  10,399  10,097  36,657  34,923   8,593   4,435
# 2     6.8     7.3     5.3     6.2     7.2     6.7     7.3     7.6     6.7
# 3    2.23    3.05    2.43    2.87    2.86    2.65    2.80    3.01    2.77
# 4     101     123     113     120     114     366     461     130      31
#
#   Q4 2021                  Métrica
# 0     864           Ore mined (kt)
# 1   8,972         Waste mined (kt)
# 2    10.4  Strip ratio (waste:ore)
# 3    2.75         Gold grade (g/t)
# 4      95           Ore mined (kt)
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 27 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en 2021-q4-txg-cp.pdf.
#
# --- Procesando: 2022-q3-txg-cp.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Gold sold (oz)",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 24 y guardada como 2022-q3-txg-cp_tabla_key_financial_metrics_Q3_2022.xlsx!
#    Q3 2022  Q1 2021  Q3 2021  Q4 2020            nombre de la métrica  \
# 0  119,834  129,019  118,989  133,063                  Gold sold (oz)
# 1   $1,715   $1,778   $1,786   $1,847      Realized gold price ($/oz)
# 2   $1,220   $1,022   $1,198   $1,075            Cost of sales ($/oz)
# 3     $760     $580     $727     $579         Total cash costs ($/oz)
# 4   $1,059     $854     $900     $886  All-in sustaining costs ($/oz)
#
#    Q2 2022  Q2 2021  Q4 2021  Q1 2022
# 0  123,363  111,424  109,391  108,012
# 1   $1,865   $1,816   $1,798   $1,876
# 2   $1,132   $1,074   $1,235   $1,224
# 3     $703     $637     $764     $748
# 4     $911     $897   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Ore mined (kt)",
#         "Q4 2020": "1,689",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883"
#     },
#     {
#     ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 23 y guardada como 2022-q3-txg-cp_tabla_key_operational_metrics_Q3_2022.xlsx!
#   Q3 2022 Q1 2021 Q3 2021 Q4 2020     nombre de la métrica Q2 2022 Q2 2021  \
# 0     883   1,359   1,406   1,689           Ore mined (kt)     987   1,131
# 1   9,097   9,882   7,476  10,399         Waste mined (kt)   7,960   8,593
# 2    10.3     7.3     5.3     6.2  Strip ratio (waste:ore)     8.1     7.6
# 3    3.02    3.05    2.43    2.87         Gold grade (g/t)    3.58    3.01
# 4     143     123     113     120           Ore mined (kt)     144     130
#
#   Q4 2021 Q1 2022
# 0     864   1,061
# 1   8,972   8,958
# 2    10.4     8.4
# 3    2.75    2.99
# 4      95     114
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 27 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 28 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 29 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 30 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 31 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 32 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en 2022-q3-txg-cp.pdf.
#
# --- Procesando: 2022-q4-txg-cp.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 26 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Gold sold (oz)",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 26 y guardada como 2022-q4-txg-cp_tabla_key_financial_metrics_Q4_2022.xlsx!
#    Q3 2022  FY 2022  Q1 2021  Q4 2022  Q3 2021  FY 2021  Q2 2022  Q2 2021  \
# 0  119,834  473,122  129,019  121,913  118,989  468,823  123,363  111,424
# 1   $1,715   $1,809   $1,778   $1,784   $1,786   $1,794   $1,865   $1,816
# 2   $1,220   $1,193   $1,022   $1,202   $1,198   $1,129   $1,132   $1,074
# 3     $760     $730     $580     $711     $727     $674     $703     $637
# 4   $1,059   $1,008     $854   $1,034     $900     $928     $911     $897
#
#    Q4 2021                          nombre  Q1 2022
# 0  109,391                  Gold sold (oz)  108,012
# 1   $1,798      Realized gold price ($/oz)   $1,876
# 2   $1,235            Cost of sales ($/oz)   $1,224
# 3     $764         Total cash costs ($/oz)     $748
# 4   $1,079  All-in sustaining costs ($/oz)   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Ore mined (kt) - ELG Open Pit",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "FY 2021"...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 25 y guardada como 2022-q4-txg-cp_tabla_key_operational_metrics_Q4_2022.xlsx!
#   Q3 2022 FY 2022 Q1 2021 Q4 2022 Q3 2021 FY 2021 Q2 2022 Q2 2021 Q4 2021  \
# 0     883   3,891   1,359     959   1,406   4,761     987   1,131     864
# 1   9,097  34,560   9,882   8,546   7,476  34,923   7,960   8,593   8,972
# 2    10.3     8.9     7.3     8.9     5.3     7.3     8.1     7.6    10.4
# 3    3.02    3.16    3.05    3.06    2.43    2.80    3.58    3.01    2.75
# 4     143     556     123     155     113     461     144     130      95
#
#                              nombre Q1 2022
# 0     Ore mined (kt) - ELG Open Pit   1,061
# 1                  Waste mined (kt)   8,958
# 2           Strip ratio (waste:ore)     8.4
# 3   Gold grade (g/t) - ELG Open Pit    2.99
# 4  Ore mined (kt) - ELG Underground     114
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 27 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 28 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 29 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 30 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 31 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 32 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 33 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 34 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en 2022-q4-txg-cp.pdf.
#
# --- Procesando: 2023-q3-txg-ep.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "métrica": "Gold sold (oz)",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749",
#         "Q3 2023": "81,752"
#    ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 25 y guardada como 2023-q3-txg-ep_tabla_key_financial_metrics_Q3_2023.xlsx!
#                           métrica  Q3 2022  Q4 2022 Q3 2023  Q2 2023  Q2 2022  \
# 0                  Gold sold (oz)  119,834  121,913  81,752  105,749  123,363
# 1      Realized gold price ($/oz)   $1,715   $1,784  $1,944   $1,960   $1,865
# 2            Cost of sales ($/oz)   $1,220   $1,202  $1,627   $1,306   $1,132
# 3         Total cash costs ($/oz)     $760     $711  $1,086     $848     $703
# 4  All-in sustaining costs ($/oz)   $1,059   $1,034  $1,450   $1,308     $911
#
#    Q4 2021  Q1 2023  Q1 2022
# 0  109,391  118,455  108,012
# 1   $1,798   $1,899   $1,876
# 2   $1,235   $1,160   $1,224
# 3     $764     $709     $748
# 4   $1,079   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Ore mined (kt) - Mining - ELG Open Pit",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644",
#         "Q3 2023": "1,026"...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 24 y guardada como 2023-q3-txg-ep_tabla_key_operational_metrics_Q3_2023.xlsx!
#   Q3 2022 Q4 2022 Q3 2023 Q2 2023  \
# 0     883     959   1,026     644
# 1   9,598  10,420  11,153   7,074
# 2   9,097   8,546  10,131  11,124
# 3    10.3     8.9     9.9    17.3
# 4    3.02    3.06    1.84    2.72
#
#                               nombre de la métrica Q2 2022 Q4 2021 Q1 2023  \
# 0           Ore mined (kt) - Mining - ELG Open Pit     987     864     916
# 1          Ore mined (tpd) - Mining - ELG Open Pit  10,846   9,392  10,182
# 2         Waste mined (kt) - Mining - ELG Open Pit   7,960   8,972   8,437
# 3  Strip ratio (waste:ore) - Mining - ELG Open Pit     8.1    10.4     9.2
# 4         Gold grade (gpt) - Mining - ELG Open Pit    3.58    2.75    4.31
#
#   Q1 2022
# 0   1,061
# 1  11,789
# 2   8,958
# 3     8.4
# 4    2.99
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Net cash generated from operating activities (M$)",
#         "Q4 2022": "$132.1",
#         "Q1 2023": "$47.0",
#         "Q2 2023": "$89.6",
#         "Q3 2023": "$44.2",
#         "LTM Q3 2023": "$312.9"
#     },
#     {
#         "nombre de la métrica": "Free cas...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 23 y guardada como 2023-q3-txg-ep_tabla_robust_cash_flow_Q3_2023.xlsx!
#   LTM Q3 2023 Q4 2022  Q3 2023  Q2 2023  \
# 0      $312.9  $132.1    $44.2    $89.6
# 1    ($120.6)   $40.5  ($69.7)  ($37.4)
# 2      $304.9   $62.6    $98.7    $77.2
# 3      $184.3  $103.1    $29.0    $39.8
# 4       427.9   121.9     81.8    105.7
#
#                                 nombre de la métrica  Q1 2023
# 0  Net cash generated from operating activities (M$)    $47.0
# 1                               Free cash flow (M$)1  ($54.0)
# 2                     Media Luna Project capex (M$)1    $66.4
# 3   Free cash flow prior to Media Luna Project (M$)1    $12.4
# 4                                    Gold sold (koz)    118.5
#
# --- Procesando: 2023-txg-q1-cp.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 26 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 27 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 28 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Gold sold (oz)",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 28 y guardada como 2023-txg-q1-cp_tabla_key_financial_metrics_QX_YYYY.xlsx!
#    Q3 2022  Q4 2022  Q3 2021            nombre de la métrica  Q2 2022  \
# 0  119,834  121,913  118,989                  Gold sold (oz)  123,363
# 1   $1,715   $1,784   $1,786      Realized gold price ($/oz)   $1,865
# 2   $1,220   $1,202   $1,198            Cost of sales ($/oz)   $1,132
# 3     $760     $711     $727         Total cash costs ($/oz)     $703
# 4   $1,059   $1,034     $900  All-in sustaining costs ($/oz)     $911
#
#    Q2 2021  Q4 2021  Q1 2023  Q1 2022
# 0  111,424  109,391  118,455  108,012
# 1   $1,816   $1,798   $1,899   $1,876
# 2   $1,074   $1,235   $1,160   $1,224
# 3     $637     $764     $709     $748
# 4     $897   $1,079   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 26 respuesta GPT:
# NO TABLE...
#
# key_operational_metrics - Página 27 respuesta GPT:
# ```json
# [
#     {
#         "Metric": "Ore mined (kt) - Mining - ELG Open Pit",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916"
#     },
#     ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 27 y guardada como 2023-txg-q1-cp_tabla_key_operational_metrics_QX_YYYY.xlsx!
#   Q3 2022 Q4 2022 Q3 2021                                    Metric Q2 2021  \
# 0     883     959   1,406    Ore mined (kt) - Mining - ELG Open Pit   1,131
# 1   9,598  10,420  15,283   Ore mined (tpd) - Mining - ELG Open Pit  12,429
# 2   9,097   8,546   7,476                          Waste mined (kt)   8,593
# 3    10.3     8.9     5.3                   Strip ratio (waste:ore)     7.6
# 4    3.02    3.06    2.43  Gold grade (gpt) - Mining - ELG Open Pit    3.01
#
#   Q2 2022 Q4 2021 Q1 2023 Q1 2022
# 0     987     864     916   1,061
# 1  10,846   9,392  10,182  11,789
# 2   7,960   8,972   8,437   8,958
# 3     8.1    10.4     9.2     8.4
# 4    3.58    2.75    4.31    2.99
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# ```json
# [
#     {
#         "métrica": "Net cash generated from operating activities ($M)",
#         "Q2 2022": "$126.9",
#         "Q3 2022": "$102.4",
#         "Q4 2022": "$132.1",
#         "Q1 2023": "$47.0",
#         "LTM Q1 2023": "$408.4"
#     },
#     {
#         "métrica": "Free cash flow ($M)",
#         "Q...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 26 y guardada como 2023-txg-q1-cp_tabla_robust_cash_flow_QX_YYYY.xlsx!
#                                              métrica Q3 2022 Q4 2022  \
# 0  Net cash generated from operating activities ($M)  $102.4  $132.1
# 1                                Free cash flow ($M)   $32.0   $40.5
# 2                      Media Luna Project capex ($M)   $32.5   $62.6
# 3    Free cash flow prior to Media Luna Project ($M)   $64.5  $103.1
# 4                                    Gold sold (koz)   119.8   121.9
#
#   LTM Q1 2023 Q2 2022  Q1 2023
# 0      $408.4  $126.9    $47.0
# 1       $91.6   $73.1  ($54.0)
# 2      $191.1   $29.6    $66.4
# 3      $282.7  $102.7    $12.4
# 4       483.6   123.4    118.5
#
# --- Procesando: 2024-08-08_-_torex_gold_-_q2_2024_earnings_presentation.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 26 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Gold sold (oz)",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749",
#         "Q3 2023": "81,752",
#         "Q4 2023": "138,794",
#         "Q1 2024": "111,642",
#         "Q2 2024": "113,513"
#     },
#    ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 26 y guardada como 2024-08-08_-_torex_gold_-_q2_2024_earnings_presentation_tabla_key_financial_metrics_Q2_2024.xlsx!
#    Q3 2022  Q4 2023  Q4 2022 Q3 2023  Q2 2023  Q2 2024  \
# 0  119,834  138,794  121,913  81,752  105,749  113,513
# 1       --       --       --      --       --  115,890
# 2   $1,715   $1,995   $1,784  $1,944   $1,960   $2,193
# 3     $760     $885     $711  $1,086     $848   $1,014
# 4   $1,059   $1,073   $1,034  $1,450   $1,308   $1,239
#
#                                nombre  Q1 2024  Q1 2023
# 0                      Gold sold (oz)  111,642  118,455
# 1      Gold equivalent sold (oz AuEq)  114,106       --
# 2  Average realized gold price ($/oz)   $2,023   $1,899
# 3             Total cash costs ($/oz)     $918     $709
# 4      All-in sustaining costs ($/oz)   $1,202   $1,079
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE...
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Ore mined (kt)",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644",
#         "Q3 2023": "1,026",
#         "Q4 2023": "1,785",
#         "Q1 2024": "969",
#         "Q2 2024": "1,622"
#     },
#     {
#         "nombre": "Ore...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 25 y guardada como 2024-08-08_-_torex_gold_-_q2_2024_earnings_presentation_tabla_key_operational_metrics_Q2_2024.xlsx!
#   Q3 2022 Q4 2023 Q4 2022 Q3 2023 Q2 2023 Q2 2024                   nombre  \
# 0     883   1,785     959   1,026     644   1,622           Ore mined (kt)
# 1   9,598  19,404  10,420  11,153   7,074  17,822          Ore mined (tpd)
# 2   9,097   7,841   8,546  10,131  11,124   7,047         Waste mined (kt)
# 3    10.3     4.4     8.9     9.9    17.3     4.3  Strip ratio (waste:ore)
# 4    3.02    2.66    3.06    1.84    2.72    2.61         Gold grade (gpt)
#
#   Q1 2024 Q1 2023
# 0     969     916
# 1  10,651  10,182
# 2   8,012   8,437
# 3     8.3     9.2
# 4    2.74    4.31
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Net cash generated from operating activities (M$)",
#         "Q3 2023": "$44.2",
#         "Q4 2023": "$120.0",
#         "Q1 2024": "$79.8",
#         "Q2 2024": "$97.4",
#         "LTM (Q2 2024)": "$341.4"
#     },
#     {
#         "nombre de la métrica": "Free c...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 24 y guardada como 2024-08-08_-_torex_gold_-_q2_2024_earnings_presentation_tabla_robust_cash_flow_Q2_2024.xlsx!
#    Q4 2023 LTM (Q2 2024)  Q3 2023  Q2 2024  \
# 0   $120.0        $341.4    $44.2    $97.4
# 1  ($24.3)      ($205.4)  ($69.7)  ($62.3)
# 2   $124.0        $457.3    $98.7   $108.2
# 3    $99.7        $251.9    $29.0    $45.9
# 4    138.8         445.7     81.8    113.5
#
#                                 nombre de la métrica  Q1 2024
# 0  Net cash generated from operating activities (M$)    $79.8
# 1                                Free cash flow (M$)  ($49.1)
# 2                      Media Luna Project capex (M$)   $126.4
# 3    Free cash flow prior to Media Luna Project (M$)    $77.3
# 4                                    Gold sold (koz)    111.6
#
# --- Procesando: 2024-q1-cp.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Gold sold (oz)",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749",
#         "Q3 2023": "81,752",
#         "Q4 2023": "138,794",
#         "Q1 2024": "111,6...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 25 y guardada como 2024-q1-cp_tabla_key_financial_metrics_Q1_2024.xlsx!
#    Q3 2022  Q4 2023  Q4 2022 Q3 2023  Q2 2023            nombre de la métrica  \
# 0  119,834  138,794  121,913  81,752  105,749                  Gold sold (oz)
# 1       --       --       --      --       --  Gold equivalent sold (oz AuEq)
# 2   $1,715   $1,995   $1,784  $1,944   $1,960      Realized gold price ($/oz)
# 3     $760     $885     $711  $1,086     $848         Total cash costs ($/oz)
# 4   $1,059   $1,073   $1,034  $1,450   $1,308  All-in sustaining costs ($/oz)
#
#    Q2 2022  Q1 2024  Q1 2023
# 0  123,363  111,642  118,455
# 1       --  114,199       --
# 2   $1,865   $2,023   $1,899
# 3     $703     $918     $709
# 4     $911   $1,202   $1,079
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "métrica": "Ore mined (kt)",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644",
#         "Q3 2023": "1,026",
#         "Q4 2023": "1,785",
#         "Q1 2024": "969"
#     },
#     {
#         "métrica": "Ore...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 24 y guardada como 2024-q1-cp_tabla_key_operational_metrics_Q1_2024.xlsx!
#                    métrica Q3 2022 Q4 2023 Q4 2022 Q3 2023 Q2 2023 Q2 2022  \
# 0           Ore mined (kt)     883   1,785     959   1,026     644     987
# 1          Ore mined (tpd)   9,598  19,404  10,420  11,153   7,074  10,846
# 2         Waste mined (kt)   9,097   7,841   8,546  10,131  11,124   7,960
# 3  Strip ratio (waste:ore)    10.3     4.4     8.9     9.9    17.3     8.1
# 4         Gold grade (gpt)    3.02    2.66    3.06    1.84    2.72    3.58
#
#   Q1 2024 Q1 2023
# 0     969     916
# 1  10,651  10,182
# 2   8,012   8,437
# 3     8.3     9.2
# 4    2.74    4.31
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Net cash generated from operating activities (M$)",
#         "Q2 2023": "$89.6",
#         "Q3 2023": "$44.2",
#         "Q4 2023": "$120.0",
#         "Q1 2024": "$79.8",
#         "LTM (Q1 2024)": "$333.6"
#     },
#     {
#         "Métrica": "Free cash flow (M$)1",
#         "...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 23 y guardada como 2024-q1-cp_tabla_robust_cash_flow_Q1_2024.xlsx!
#    Q4 2023  Q1 2024  Q3 2023  Q2 2023 LTM (Q1 2024)  \
# 0   $120.0    $79.8    $44.2    $89.6        $333.6
# 1  ($24.3)  ($49.1)  ($69.7)  ($37.4)      ($180.5)
# 2   $124.0   $126.4    $98.7    $77.2        $426.3
# 3    $99.7    $77.3    $29.0    $39.8        $245.8
# 4    138.8    111.6     81.8    105.7         437.9
#
#                                              Métrica
# 0  Net cash generated from operating activities (M$)
# 1                               Free cash flow (M$)1
# 2                     Media Luna Project capex (M$)1
# 3   Free cash flow prior to Media Luna Project (M$)1
# 4                                    Gold sold (koz)
#
# --- Procesando: 2025-02-20_-_torex_gold_-_q4_2024_earnings_presentation.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Gold sold (koz)",
#         "Q1 2023": "118.5",
#         "Q2 2023": "105.7",
#         "Q3 2023": "81.8",
#         "Q4 2023": "138.8",
#         "Q1 2024": "111.6",
#         "Q2 2024": "113.5",
#         "Q3 2024": "122.1",
#         "Q4 2024": "108.6",
#         "FY 2023": "444...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 24 y guardada como 2025-02-20_-_torex_gold_-_q4_2024_earnings_presentation_tabla_key_financial_metrics_Q4_2024.xlsx!
#   FY 2023 Q4 2023 Q1 2024 Q3 2023 Q2 2023 Q2 2024 Q4 2024  \
# 0   444.8   138.8   111.6    81.8   105.7   113.5   108.6
# 1   451.2   139.8   114.1    83.3   107.4   115.9   110.4
# 2  $1,952  $1,995  $2,023  $1,944  $1,960  $2,193  $2,487
# 3    $866    $885    $918  $1,086    $848  $1,014    $902
# 4  $1,200  $1,073  $1,202  $1,450  $1,308  $1,239  $1,085
#
#                               Métrica Q1 2023 Q3 2024 FY 2024
# 0                     Gold sold (koz)   118.5   122.1   455.9
# 1     Gold equivalent sold (koz AuEq)   120.7   125.4   465.8
# 2  Average realized gold price ($/oz)  $1,899  $2,313  $2,254
# 3             Total cash costs ($/oz)    $709    $926    $940
# 4      All-in sustaining costs ($/oz)  $1,079  $1,101  $1,156
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Ore mined (kt)",
#         "Q1 2023": 916,
#         "Q2 2023": 644,
#         "Q3 2023": 1026,
#         "Q4 2023": 1785,
#         "Q1 2024": 969,
#         "Q2 2024": 1622,
#         "Q3 2024": 1539,
#         "Q4 2024": 852,
#         "FY 2023": 4371,
#         "FY 2...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 23 y guardada como 2025-02-20_-_torex_gold_-_q4_2024_earnings_presentation_tabla_key_operational_metrics_Q4_2024.xlsx!
#     FY 2023   Q4 2023   Q3 2023   Q2 2023     nombre de la métrica   Q2 2024  \
# 0   4371.00   1785.00   1026.00    644.00           Ore mined (kt)   1622.00
# 1  11976.00  19404.00  11153.00   7074.00          Ore mined (tpd)  17822.00
# 2  37533.00   7841.00  10131.00  11124.00         Waste mined (kt)   7047.00
# 3      8.60      4.40      9.90     17.30  Strip ratio (waste:ore)      4.30
# 4      2.82      2.66      1.84      2.72         Gold grade (gpt)      2.61
#
#    Q4 2024   Q1 2024   Q1 2023   Q3 2024   FY 2024
# 0   852.00    969.00    916.00   1539.00   4982.00
# 1  9256.00  10651.00  10182.00  16731.00  13611.00
# 2  1548.00   8012.00   8437.00   4299.00  20906.00
# 3     1.80      8.30      9.20      2.80      4.20
# 4     2.89      2.74      4.31      2.72      2.72
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 27 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en 2025-02-20_-_torex_gold_-_q4_2024_earnings_presentation.pdf.
#
# --- Procesando: q1_2021_presentation_final_-_may_13_2021.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# ```json
# [
#     {
#         "Metric": "Gold sold (oz)",
#         "Q2 2019": "113,419",
#         "Q3 2019": "132,535",
#         "Q4 2019": "126,910",
#         "Q1 2020": "108,064",
#         "Q2 2020": "63,147",
#         "Q3 2020": "133,036",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019"
#     },
#    ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 21 y guardada como q1_2021_presentation_final_-_may_13_2021_tabla_key_financial_metrics_Q1_2021.xlsx!
#    Q2 2019  Q1 2020  Q1 2021  Q3 2019  Q4 2020  Q3 2020  \
# 0  113,419  108,064  129,019  132,535  133,063  133,036
# 1   $1,314   $1,571   $1,778   $1,478   $1,847   $1,884
# 2   $1,020   $1,333   $1,022     $982   $1,075   $1,154
# 3     $606     $794     $580     $561     $579     $633
# 4     $760     $975     $854     $675     $886     $877
#
#                           Metric Q2 2020  Q4 2019
# 0                 Gold sold (oz)  63,147  126,910
# 1     Realized gold price ($/oz)  $1,712   $1,481
# 2           Cost of sales ($/oz)  $1,447   $1,174
# 3         Total cash cost ($/oz)    $740     $617
# 4  All-in sustaining cost ($/oz)  $1,015     $767
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'KEY OPERATIONAL METRICS' en q1_2021_presentation_final_-_may_13_2021.pdf.
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en q1_2021_presentation_final_-_may_13_2021.pdf.
#
# --- Procesando: q2_2021_earnings_call_presentation_-_final_aug_5-_2.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Gold sold (oz)",
#         "Q3 2019": "132,535",
#         "Q4 2019": "126,910",
#         "Q1 2020": "108,064",
#         "Q2 2020": "63,147",
#         "Q3 2020": "133,036",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,4...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 22 y guardada como q2_2021_earnings_call_presentation_-_final_aug_5-_2_tabla_key_financial_metrics_Q2_2021.xlsx!
#    Q1 2020  Q1 2021  Q3 2019           nombre de la métrica  Q3 2020  Q4 2020  \
# 0  108,064  129,019  132,535                 Gold sold (oz)  133,036  133,063
# 1   $1,571   $1,778   $1,478     Realized gold price ($/oz)   $1,884   $1,847
# 2   $1,333   $1,022     $982           Cost of sales ($/oz)   $1,154   $1,075
# 3     $794     $580     $561         Total cash cost ($/oz)     $633     $579
# 4     $975     $854     $675  All-in sustaining cost ($/oz)     $877     $886
#
#    Q2 2021 Q2 2020  Q4 2019
# 0  111,424  63,147  126,910
# 1   $1,816  $1,712   $1,481
# 2   $1,074  $1,447   $1,174
# 3     $637    $740     $617
# 4     $897  $1,015     $767
# key_operational_metrics - Página 21 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Ore mined (kt) - Open Pit",
#         "Q3 2019": "1,314",
#         "Q4 2019": "1,475",
#         "Q1 2020": "1,736",
#         "Q2 2020": "666",
#         "Q3 2020": "1,407",
#         "Q4 2020": "1,689",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131"
#     },
#     {
#    ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 21 y guardada como q2_2021_earnings_call_presentation_-_final_aug_5-_2_tabla_key_operational_metrics_Q2_2021.xlsx!
#   Q1 2020 Q1 2021 Q3 2019 Q4 2020 Q3 2020 Q2 2021 Q2 2020 Q4 2019  \
# 0   1,736   1,359   1,314   1,689   1,407   1,131     666   1,475
# 1  11,726   9,882  11,923  10,399  10,097   8,593   4,435  10,795
# 2     6.8     7.3     9.1     6.2     7.2     7.6     6.7     7.3
# 3    2.23    3.05    2.87    2.87    2.86    3.01    2.77    2.75
# 4     101     123     102     120     114     130      31      98
#
#                          nombre
# 0     Ore mined (kt) - Open Pit
# 1              Waste mined (kt)
# 2       Strip ratio (waste:ore)
# 3   Gold grade (g/t) - Open Pit
# 4  Ore mined (kt) - Underground
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en q2_2021_earnings_call_presentation_-_final_aug_5-_2.pdf.
#
# --- Procesando: q3_2021_earnings_call_presentation_-_final.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# ```json
# [
#     {
#         "Metric": "Gold sold (oz)",
#         "Q4 2019": "126,910",
#         "Q1 2020": "108,064",
#         "Q2 2020": "63,147",
#         "Q3 2020": "133,063",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989"
#     },
#    ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 22 y guardada como q3_2021_earnings_call_presentation_-_final_tabla_key_financial_metrics_Q3_2021.xlsx!
#    Q1 2020  Q1 2021  Q3 2021  Q4 2020  Q3 2020                         Metric  \
# 0  108,064  129,019  118,989  133,063  133,063                 Gold sold (oz)
# 1   $1,571   $1,778   $1,786   $1,847   $1,884     Realized gold price ($/oz)
# 2   $1,333   $1,022   $1,198   $1,075   $1,154           Cost of sales ($/oz)
# 3     $794     $580     $727     $579     $633         Total cash cost ($/oz)
# 4     $975     $854     $900     $886     $877  All-in sustaining cost ($/oz)
#
#    Q2 2021 Q2 2020  Q4 2019
# 0  111,424  63,147  126,910
# 1   $1,816  $1,712   $1,481
# 2   $1,074  $1,447   $1,174
# 3     $637    $740     $617
# 4     $897  $1,015     $767
# key_operational_metrics - Página 21 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Q4 2019",
#         "Ore mined (kt)": 1475,
#         "Waste mined (kt)": 10795,
#         "Strip ratio (waste:ore)": 7.3,
#         "Gold grade (g/t)": 2.75,
#         "Ore mined (kt) Underground": 98,
#         "Gold grade (g/t) Underground": 7.65,
#         "Ore mined (kt) To...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 21 y guardada como q3_2021_earnings_call_presentation_-_final_tabla_key_operational_metrics_Q3_2021.xlsx!
#    Waste mined (kt)  Gold grade (g/t) Processing  Gold produced (oz)  \
# 0             10795                         3.87              125151
# 1             11726                         3.35              108537
# 2              4435                         3.18               59508
# 3             10097                         3.83              131790
# 4             10399                         4.01              130649
#
#    Gold grade (g/t)  Gold sold (oz)  Strip ratio (waste:ore)  \
# 0              2.75          126910                      7.3
# 1              2.23          108064                      6.8
# 2              2.77           63147                      6.7
# 3              2.86          133036                      7.2
# 4              2.87          133063                      6.2
#
#    Gold grade (g/t) Total  Gold recovery (%)  Ore mined (kt) Total  \
# 0                    3.06                 89                  1573
# 1                    2.52                 89                  1837
# 2                    3.07                 89                   697
# 3                    3.15                 89                  1521
# 4                    3.14                 89                  1809
#
#    Ore mined (kt)  Ore processed (kt)  Ore mined (kt) Underground   nombre  \
# 0            1475                1116                          98  Q4 2019
# 1            1736                1134                         101  Q1 2020
# 2             666                 688                          31  Q2 2020
# 3            1407                1184                         114  Q3 2020
# 4            1689                1156                         120  Q4 2020
#
#    Gold grade (g/t) Underground  Ore processed (tpd)
# 0                          7.65                12130
# 1                          7.50                12464
# 2                          9.49                 7560
# 3                          6.76                12870
# 4                          7.02                12565
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en q3_2021_earnings_call_presentation_-_final.pdf.
#
# --- Procesando: q4_2023_txg_ep.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# NO TABLE...
#
# key_financial_metrics - Página 26 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 27 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Gold sold (oz)",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749",
#         "Q3 2023": "81,752",
#         "Q4 2023": "138,794",
#         ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 27 y guardada como q4_2023_txg_ep_tabla_key_financial_metrics_Q4_2023.xlsx!
#    Q3 2022  FY 2022  Q4 2023  FY 2023  Q4 2022 Q3 2023  Q2 2023  Q2 2022  \
# 0  119,834  473,122  138,794  444,750  121,913  81,752  105,749  123,363
# 1   $1,715   $1,809   $1,995   $1,952   $1,784  $1,944   $1,960   $1,865
# 2   $1,220   $1,193   $1,368   $1,345   $1,202  $1,627   $1,306   $1,132
# 3     $760     $730     $885     $866     $711  $1,086     $848     $703
# 4   $1,059   $1,008   $1,073   $1,200   $1,034  $1,450   $1,308     $911
#
#                           Métrica  Q1 2023  Q1 2022
# 0                  Gold sold (oz)  118,455  108,012
# 1      Realized gold price ($/oz)   $1,899   $1,876
# 2            Cost of sales ($/oz)   $1,160   $1,224
# 3         Total cash costs ($/oz)     $709     $748
# 4  All-in sustaining costs ($/oz)   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 26 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Ore mined (kt) - ELG Open Pit",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644",
#         "Q3 2023": "1,026",
#         "Q4 2023": "1,785",
#      ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 26 y guardada como q4_2023_txg_ep_tabla_key_operational_metrics_Q4_2023.xlsx!
#   Q3 2022 FY 2022 Q4 2023 FY 2023 Q4 2022 Q3 2023 Q2 2023  \
# 0     883   3,891   1,785   4,371     959   1,026     644
# 1   9,598  10,660  19,404  11,976  10,420  11,153   7,074
# 2   9,097  34,560   7,841  37,533   8,546  10,131  11,124
# 3    10.3     8.9     4.4     8.6     8.9     9.9    17.3
# 4    3.02    3.16    2.66    2.82    3.06    1.84    2.72
#
#                      nombre de la métrica Q2 2022 Q1 2023 Q1 2022
# 0           Ore mined (kt) - ELG Open Pit     987     916   1,061
# 1          Ore mined (tpd) - ELG Open Pit  10,846  10,182  11,789
# 2         Waste mined (kt) - ELG Open Pit   7,960   8,437   8,958
# 3  Strip ratio (waste:ore) - ELG Open Pit     8.1     9.2     8.4
# 4         Gold grade (gpt) - ELG Open Pit    3.58    4.31    2.99
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Net cash generated from operating activities (M$)",
#         "Q1 2023": "$47.0",
#         "Q2 2023": "$89.6",
#         "Q3 2023": "$44.2",
#         "Q4 2023": "$120.0",
#         "Full Year 2023": "$300.8"
#     },
#     {
#         "nombre de la métrica": "Free ...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 25 y guardada como q4_2023_txg_ep_tabla_robust_cash_flow_Q4_2023.xlsx!
#    Q4 2023  Q3 2023  Q2 2023  \
# 0   $120.0    $44.2    $89.6
# 1  ($24.3)  ($69.7)  ($37.4)
# 2   $124.0    $98.7    $77.2
# 3    $99.7    $29.0    $39.8
# 4    138.8     81.8    105.7
#
#                                 nombre de la métrica  Q1 2023 Full Year 2023
# 0  Net cash generated from operating activities (M$)    $47.0         $300.8
# 1                               Free cash flow (M$)1  ($54.0)       ($185.4)
# 2                     Media Luna Project capex (M$)1    $66.4         $366.3
# 3   Free cash flow prior to Media Luna Project (M$)1    $12.4         $180.9
# 4                                    Gold sold (koz)    118.5          444.8
#
# --- Procesando: torex_gold_-_q1_2022_earnings_presentation_-_may_11_fin.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "Metric Name": "Gold sold (oz)",
#         "Q2 2020": "63,147",
#         "Q3 2020": "133,036",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012"
#     }...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 23 y guardada como torex_gold_-_q1_2022_earnings_presentation_-_may_11_fin_tabla_key_financial_metrics_Q1_2022.xlsx!
#    Q1 2021                    Metric Name  Q3 2021  Q4 2020  Q3 2020  Q2 2021  \
# 0  129,019                 Gold sold (oz)  118,989  133,063  133,036  111,424
# 1   $1,778     Realized gold price ($/oz)   $1,786   $1,847   $1,884   $1,816
# 2   $1,022           Cost of sales ($/oz)   $1,198   $1,075   $1,154   $1,074
# 3     $580         Total cash cost ($/oz)     $727     $579     $633     $637
# 4     $854  All-in sustaining cost ($/oz)     $900     $886     $877     $897
#
#   Q2 2020  Q4 2021  Q1 2022
# 0  63,147  109,391  108,012
# 1  $1,712   $1,798   $1,876
# 2  $1,447   $1,235   $1,224
# 3    $740     $764     $748
# 4  $1,015   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Ore mined (kt)",
#         "Q2 2020": "666",
#         "Q3 2020": "1,407",
#         "Q4 2020": "1,689",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061"
#     },
#     {
#         "nombre"...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 22 y guardada como torex_gold_-_q1_2022_earnings_presentation_-_may_11_fin_tabla_key_operational_metrics_Q1_2022.xlsx!
#   Q1 2021 Q3 2021 Q4 2020 Q3 2020 Q2 2021 Q2 2020 Q4 2021  \
# 0   1,359   1,406   1,689   1,407   1,131     666     864
# 1   9,882   7,476  10,399  10,097   8,593   4,435   8,972
# 2     7.3     5.3     6.2     7.2     7.6     6.7    10.4
# 3    3.05    2.43    2.87    2.86    3.01    2.77    2.75
# 4     123     113     120     114     130      31      95
#
#                        nombre Q1 2022
# 0              Ore mined (kt)   1,061
# 1            Waste mined (kt)   8,958
# 2     Strip ratio (waste:ore)     8.4
# 3            Gold grade (g/t)    2.99
# 4  Ore mined (kt) Underground     114
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en torex_gold_-_q1_2022_earnings_presentation_-_may_11_fin.pdf.
#
# --- Procesando: torex_gold_-_q2_2022_earnings_presentation_final.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "nombre de la métrica": "Gold sold (oz)",
#         "Q3 2020": "133,036",
#         "Q4 2020": "133,063",
#         "Q1 2021": "129,019",
#         "Q2 2021": "111,424",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 24 y guardada como torex_gold_-_q2_2022_earnings_presentation_final_tabla_key_financial_metrics_Q2_2022.xlsx!
#    Q1 2021  Q3 2021  Q4 2020            nombre de la métrica  Q3 2020  \
# 0  129,019  118,989  133,063                  Gold sold (oz)  133,036
# 1   $1,778   $1,786   $1,847      Realized gold price ($/oz)   $1,884
# 2   $1,022   $1,198   $1,075            Cost of sales ($/oz)   $1,154
# 3     $580     $727     $579         Total cash costs ($/oz)     $633
# 4     $854     $900     $886  All-in sustaining costs ($/oz)     $877
#
#    Q2 2022  Q2 2021  Q4 2021  Q1 2022
# 0  123,363  111,424  109,391  108,012
# 1   $1,865   $1,816   $1,798   $1,876
# 2   $1,132   $1,074   $1,235   $1,224
# 3     $703     $637     $764     $748
# 4     $911     $897   $1,079   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "métrica": "Ore mined (kt) - ELG Open Pit",
#         "Q3 2020": "1,407",
#         "Q4 2020": "1,689",
#         "Q1 2021": "1,359",
#         "Q2 2021": "1,131",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987"
#     },
#     {
# ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 23 y guardada como torex_gold_-_q2_2022_earnings_presentation_final_tabla_key_operational_metrics_Q2_2022.xlsx!
#                             métrica Q1 2021 Q3 2021 Q4 2020 Q3 2020 Q2 2022  \
# 0     Ore mined (kt) - ELG Open Pit   1,359   1,406   1,689   1,407     987
# 1                  Waste mined (kt)   9,882   7,476  10,399  10,097   7,960
# 2           Strip ratio (waste:ore)     7.3     5.3     6.2     7.2     8.1
# 3   Gold grade (g/t) - ELG Open Pit    3.05    2.43    2.87    2.86    3.58
# 4  Ore mined (kt) - ELG Underground     123     113     120     114     144
#
#   Q2 2021 Q4 2021 Q1 2022
# 0   1,131     864   1,061
# 1   8,593   8,972   8,958
# 2     7.6    10.4     8.4
# 3    3.01    2.75    2.99
# 4     130      95     114
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 25 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 26 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 27 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 28 respuesta GPT:
# NO TABLE...
#
# robust_cash_flow - Página 29 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 30 respuesta GPT:
# NO TABLE....
#
# No se encontró la tabla 'ROBUST CASH FLOW GENERATION FROM ELG' en torex_gold_-_q2_2022_earnings_presentation_final.pdf.
#
# --- Procesando: torex_gold_-_q2_2023_earnings_presentation_2023-08-02.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "nombre": "Gold sold (oz)",
#         "Q3 2021": "118,989",
#         "Q4 2021": "109,391",
#         "Q1 2022": "108,012",
#         "Q2 2022": "123,363",
#         "Q3 2022": "119,834",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749"
#     },
#   ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 25 y guardada como torex_gold_-_q2_2023_earnings_presentation_2023-08-02_tabla_key_financial_metrics_Q2_2023.xlsx!
#    Q3 2022  Q4 2022  Q3 2021  Q2 2023  Q2 2022  Q1 2023  Q4 2021  \
# 0  119,834  121,913  118,989  105,749  123,363  118,455  109,391
# 1   $1,715   $1,784   $1,786   $1,960   $1,865   $1,899   $1,798
# 2   $1,220   $1,202   $1,198   $1,306   $1,132   $1,160   $1,235
# 3     $760     $711     $727     $848     $703     $709     $764
# 4   $1,059   $1,034     $900   $1,308     $911   $1,079   $1,079
#
#                            nombre  Q1 2022
# 0                  Gold sold (oz)  108,012
# 1      Realized gold price ($/oz)   $1,876
# 2            Cost of sales ($/oz)   $1,224
# 3         Total cash costs ($/oz)     $748
# 4  All-in sustaining costs ($/oz)   $1,034
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "nombre_metrica": "Ore mined (kt) - ELG Open Pit",
#         "Q3 2021": "1,406",
#         "Q4 2021": "864",
#         "Q1 2022": "1,061",
#         "Q2 2022": "987",
#         "Q3 2022": "883",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644"
#     },
#     {
#  ...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 24 y guardada como torex_gold_-_q2_2023_earnings_presentation_2023-08-02_tabla_key_operational_metrics_Q2_2023.xlsx!
#   Q3 2022                          nombre_metrica Q4 2022 Q3 2021 Q2 2023  \
# 0     883           Ore mined (kt) - ELG Open Pit     959   1,406     644
# 1   9,598          Ore mined (tpd) - ELG Open Pit  10,420  15,283   7,074
# 2   9,097         Waste mined (kt) - ELG Open Pit   8,546   7,476  11,124
# 3    10.3  Strip ratio (waste:ore) - ELG Open Pit     8.9     5.3    17.3
# 4    3.02         Gold grade (gpt) - ELG Open Pit    3.06    2.43    2.72
#
#   Q2 2022 Q4 2021 Q1 2023 Q1 2022
# 0     987     864     916   1,061
# 1  10,846   9,392  10,182  11,789
# 2   7,960   8,972   8,437   8,958
# 3     8.1    10.4     9.2     8.4
# 4    3.58    2.75    4.31    2.99
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# ```json
# [
#     {
#         "Nombre de la métrica": "Net cash generated from operating activities (M$)",
#         "Q3 2022": "$102.4",
#         "Q4 2022": "$132.1",
#         "Q1 2023": "$47.0",
#         "Q2 2023": "$89.6",
#         "LTM Q2 2023": "$371.1"
#     },
#     {
#         "Nombre de la métrica": "Free ca...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 23 y guardada como torex_gold_-_q2_2023_earnings_presentation_2023-08-02_tabla_robust_cash_flow_Q2_2023.xlsx!
#   Q3 2022 Q4 2022  Q2 2023                               Nombre de la métrica  \
# 0  $102.4  $132.1    $89.6  Net cash generated from operating activities (M$)
# 1   $32.0   $40.5  ($37.4)                                Free cash flow (M$)
# 2   $32.5   $62.6    $77.2                      Media Luna Project capex (M$)
# 3   $64.5  $103.1    $39.8    Free cash flow prior to Media Luna Project (M$)
# 4   119.8   121.9    105.7                                    Gold sold (koz)
#
#   LTM Q2 2023  Q1 2023
# 0      $371.1    $47.0
# 1     ($18.9)  ($54.0)
# 2      $238.7    $66.4
# 3      $219.8    $12.4
# 4       466.0    118.5
#
# --- Procesando: txg_cp_q3_2024.pdf ---
# key_financial_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 25 respuesta GPT:
# NO TABLE....
#
# key_financial_metrics - Página 26 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Gold sold (oz)",
#         "Q4 2022": "121,913",
#         "Q1 2023": "118,455",
#         "Q2 2023": "105,749",
#         "Q3 2023": "81,752",
#         "Q4 2023": "138,794",
#         "Q1 2024": "111,642",
#         "Q2 2024": "113,513",
#         "Q3 2024": "122,130"
#     },
#   ...
#
# ¡Tabla 'KEY FINANCIAL METRICS' encontrada en página 26 y guardada como txg_cp_q3_2024_tabla_key_financial_metrics_Q3_2024.xlsx!
#    Q4 2023  Q1 2024  Q4 2022 Q3 2023  Q2 2023  Q2 2024  \
# 0  138,794  111,642  121,913  81,752  105,749  113,513
# 1  114,106  115,890       --      --       --  125,414
# 2   $1,995   $2,023   $1,784  $1,944   $1,960   $2,193
# 3     $885     $918     $711  $1,086     $848   $1,014
# 4   $1,073   $1,202   $1,034  $1,450   $1,308   $1,239
#
#                               Métrica  Q1 2023  Q3 2024
# 0                      Gold sold (oz)  118,455  122,130
# 1      Gold equivalent sold (oz AuEq)       --  125,414
# 2  Average realized gold price ($/oz)   $1,899   $2,313
# 3             Total cash costs ($/oz)     $709     $926
# 4      All-in sustaining costs ($/oz)   $1,079   $1,101
# key_operational_metrics - Página 21 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 22 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 23 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 24 respuesta GPT:
# NO TABLE....
#
# key_operational_metrics - Página 25 respuesta GPT:
# ```json
# [
#     {
#         "Metric": "Ore mined (kt)",
#         "Q4 2022": "959",
#         "Q1 2023": "916",
#         "Q2 2023": "644",
#         "Q3 2023": "1,026",
#         "Q4 2023": "1,785",
#         "Q1 2024": "969",
#         "Q2 2024": "1,622",
#         "Q3 2024": "1,539"
#     },
#     {
#         "Metric": "O...
#
# ¡Tabla 'KEY OPERATIONAL METRICS' encontrada en página 25 y guardada como txg_cp_q3_2024_tabla_key_operational_metrics_Q3_2024.xlsx!
#   Q4 2023 Q4 2022 Q3 2023 Q2 2023 Q2 2024                   Metric Q1 2024  \
# 0   1,785     959   1,026     644   1,622           Ore mined (kt)     969
# 1  19,404  10,420  11,153   7,074  17,822          Ore mined (tpd)  10,651
# 2   7,841   8,546  10,131  11,124   7,047         Waste mined (kt)   8,012
# 3     4.4     8.9     9.9    17.3     4.3  Strip ratio (waste:ore)     8.3
# 4    2.66    3.06    1.84    2.72    2.61         Gold grade (gpt)    2.74
#
#   Q1 2023 Q3 2024
# 0     916   1,539
# 1  10,182  16,731
# 2   8,437   4,299
# 3     9.2     2.8
# 4    4.31    2.72
# robust_cash_flow - Página 21 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 22 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 23 respuesta GPT:
# NO TABLE....
#
# robust_cash_flow - Página 24 respuesta GPT:
# ```json
# [
#     {
#         "Métrica": "Net cash generated from operating activities (M$)",
#         "Q4 2023": "$120.0",
#         "Q1 2024": "$79.8",
#         "Q2 2024": "$97.4",
#         "Q3 2024": "$149.5",
#         "LTM (Q3 2024)": "$446.7"
#     },
#     {
#         "Métrica": "Free cash flow (M$)",
#         "...
#
# ¡Tabla 'ROBUST CASH FLOW GENERATION FROM ELG' encontrada en página 24 y guardada como txg_cp_q3_2024_tabla_robust_cash_flow_Q3_2024.xlsx!
#    Q4 2023  Q1 2024  Q2 2024 LTM (Q3 2024)  \
# 0   $120.0    $79.8    $97.4        $446.7
# 1  ($24.3)  ($49.1)  ($62.3)      ($136.4)
# 2   $124.0   $126.4   $108.2        $472.5
# 3    $99.7    $77.3    $45.9        $336.1
# 4    138.8    111.6    113.5         486.1
#
#                                              Métrica Q3 2024
# 0  Net cash generated from operating activities (M$)  $149.5
# 1                                Free cash flow (M$)  ($0.7)
# 2                      Media Luna Project capex (M$)  $113.9
# 3    Free cash flow prior to Media Luna Project (M$)  $113.2
# 4                                    Gold sold (koz)   122.1
